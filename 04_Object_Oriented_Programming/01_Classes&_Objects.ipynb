# %% [markdown]
# ---
# **Object Oriented Programming (O.O.P.)**
# - The core entities of OOP are **classes** and **objects**.
#
# **Classes**
#
# - Think of classes as user-defined data types.
# - When you define a class, you essentially define how this new data type is going to be like
# - Mainly you define two things:
#     - what kind of data it is going to store.
#     - what kind of operations it is going to support.
#
# **Objects**
#
# - Think of objects as variables of these user-defined data types.
# - When you initialize an object, you have created a variable that is going to store data and support operations as defined in the corresponding class.
# - The data that an object stores are called its _attributes_.
# - The operations that an object supports are called its _methods_.

# %%
# Lets create a class to store Time as an object

class Time:
    def __init__(self, hour, minute):   # constructor: special function that is called when an object is created
        self.hour = hour                # a Time object is going to store two int values: hour and minute
        self.minute = minute

# main starts here
time1 = Time(12, 30)                    # creating an Object of Time class

print(f"{time1 = }")                    # trying to print the object of Time class
print(f"{time1.hour   = }")               # trying to print the value of hour attribute of Time class
print(f"{time1.minute = }")             # trying to print the value of minute attribute of Time class
# Out:
# time1 = <__main__.Time object at 0x0000018C1FAEBB60>
# time1.hour   = 12
# time1.minute = 30

# %% [markdown]
# **HOMEWORK**: Complete the definition of Date class by adding three attributes: day, month, year

# %%
class Date:
     def __init__(self, day, month, year):
          self.day = day
          self.month = month
          self.year = year

# main starts here
date = Date(21,4,2025)

print(f"{date = }")
print(f"{date.day   = }")
print(f"{date.month = }")
print(f"{date.year  = }")
# Out:
# date = <__main__.Date object at 0x0000018C1FAEBA10>
# date.day   = 21
# date.month = 4
# date.year  = 2025

# %% [markdown]
# ---
# **Interaction of objects with python features**
#
# - One of the first interactions that you may think of is to print an object using `print()` function.
# - If try to print an object using print function you won't see anything meaningful.
# - To print it properly, you need to define the `__repr__` method.
# - The `__repr__` method is a special dunder method (just like `__init__` method).
# - `__repr__` method defines how your object should be represented/printed.
# - You can decide hwo descriptive you want it to be.
# What to hide, what to show, in what order, in what format, everything.
# - These methods are meant to serve unique purposes. More about them later.

# %%
class without_repr:               # class without `__repr__` method
    def __init__(self, val):
        self.val = val
    
class with_repr:                  # class with `__repr__` method
    def __init__(self, val):
        self.val = val
    def __repr__(self):
        return f"value = {self.val}"    # you can format it the way you want

# main starts here
object_1 = without_repr(10)
print(object_1)

object_2 = with_repr(10)
print(object_2)
# Out:
# ...
# value = 10

# %%
class Time:
    def __init__(self, hour, minute):
        self.hour = hour
        self.minute = minute
    def __repr__(self):
        return f"{self.hour:02}:{self.minute:02}"

# main starts here
time1 = Time(6, 7)      # creating an object of Time class
print(f"{time1 = }")    # printing the object of Time class
# Out:
# time1 = 06:07

# %% [markdown]
# **HOMEWORK**: Define the Date class by adding:
# - three attributes — day, month, year and
# - `__repr__` method to print the in the `DD/MM/YYYY` format:
#
#     ```Text
#     Date(7,8,2026) => 07/08/2026
#     ```

# %%
class Date:
    def __init__(self, day, month, year):
        self.day = day
        self.month = month
        self.year = year
    def __repr__(self):
        return f"{self.day:02}/{self.month:02}/{self.year}"

# main starts here
today = Date(7,8,2026)
print(today)
# Out:
# 07/08/2026

# %% [markdown]
# ---
# **Interaction between classes**
#
# - One reason to use OOP is to mimic real-life objects using programming.
# - After creating objects and defining their attributes, the next thing we need to do is to define how will these objects are going to interact with each other.
# - The objects may interact with other objects of the same class as well as objects of other classes.
# - To define these interactions we have to define some **methods**.
#
# - Think of methods as functions that are defined inside a class.
# - A method defined inside a class can only be used by objects of that class, or the class itself.

# %%
# Class to define a period of time
class TimePeriod:
    def __init__(self, minutes):
        self.minutes = minutes
    def __repr__(self):
        return f"{self.minutes} minutes"

# Class to define a point in time
class Time:
    def __init__(self, hour, minute):
        self.hour = hour
        self.minute = minute
    def __repr__(self):
        return f"{self.hour:02}:{self.minute:02}"
    
    # this method calculates the TimePeriod between two times
    # interaction between two objects of the same class
    def diff(self, other):
        total_minutes_1 = (self.hour * 60) + self.minute
        total_minutes_2 = (other.hour * 60) + other.minute
        period_in_minutes = total_minutes_1 - total_minutes_2
        return TimePeriod(period_in_minutes)
    
    # this method calculates the time after given time period
    # interaction between two objects of different classes
    def after(self, period):
        total_minutes_1 = (self.hour) * 60 + self.minute
        period_in_minutes = period.minutes
        total_minutes_2 = total_minutes_1 + period_in_minutes
        hour   = total_minutes_2 // 60
        minute = total_minutes_2 % 60
        return Time(hour, minute)


# main starts here

# Example 1: The class started at 04:21 and the current time is 05:14.
# I want to calculate how much time has passed
start_time = Time(16, 21)
curr_time = Time(17, 14)
time_passed = curr_time.diff(start_time)
print(f"Time passed: {time_passed}")

# Example 2: The class started at 04:21 and its supposed duration is 100 minutes.
# I want to calculate the end time for the class
start_time = Time(16, 21)
duration = TimePeriod(100)
end_time = start_time.after(duration)
print(f"End time: {end_time}")
# Out:
# Time passed: 53 minutes
# End time: 18:01

# %% [markdown]
# ---
# **Instance & Class members**
# - Instance members are those members _(attributes and methods)_ which are associated with each instance _(object)_ of a class.
# - Class members are those members _(attributes and methods)_ which are shared by each instance _(object)_ of a class.

# %%
class Student:
    # CLASS ATTRIBUTES : common for all objects of this class
    count = 0

    def __init__(self, name, marks):
        # INSTANCE ATTRIBUTES : unique for all objects of this class
        self.name = name
        self.marks = marks
        self.incrCounter()

    # CLASS METHOD : common for all objects of this class
    #                can only access class members and not instance members
    #                has `cls` as the first argument
    @classmethod
    def incrCounter(cls):
        cls.count += 1
    
    @classmethod
    def showCounter(cls):
        print(f"Total: {cls.count}")

    # INSTANCE METHOD : unique for all objects of this class
    #                   can access both class members and instance members
    #                   has `self` as the first argument
    def show_details(self):
        percent = self.percentage(self.marks, total_marks=150)
        print(f"Name : {self.name}")
        print(f"Marks: {self.marks}")
        print(f"Perc : {percent:.2f}%")
        print()

    # STATIC METHOD : common for all objects of this class
    #                 can access neither class members nor instance members 
    #                 used for making utility function that doesn't require access
    @staticmethod
    def percentage(marks_obtained, total_marks):
        return (marks_obtained/total_marks)*100

# main starts here
s1 = Student('Swayam', 87)
s2 = Student('Siddhu', 97)
s3 = Student('Rohan', 92)

s1.show_details()
s2.show_details()
s3.show_details()
# Student.showCounter()   # Invalid: we cannot access class members via objects

s1.showCounter()
s2.showCounter()
s3.showCounter()
Student.showCounter()

# %%
class Family_Member:
    room_count = 4
    def __init__(self, name, age):
        self.name = name
        self.age = age

# room_count is a class attribute hence we can access it via the class
# even if we don't have created any objects yet
print("initially when there's no member")
print(f"{Family_Member.room_count = }")
print()

# once we create an object of the class we can access it in two ways:
# - directly via the class
# - via the object (this will still refer to the class attribute as the objects doesn't have their own copy)
swayam = Family_Member("Swayam", 13)
print("after adding the first member")
print(f"{Family_Member.room_count = }")
print(f"{swayam.room_count            = }")
print()

# if we create multiple objects, we can access the class attribute via the class or any of its objects
# all of these will refer to the same class attribute, as objects don't have their own copies
siddhu = Family_Member("Siddhu", 20)
print("after adding the second member")
print(f"{Family_Member.room_count = }")
print(f"{swayam.room_count            = }")
print(f"{siddhu.room_count            = }")
print()

# if we update this value via the class, it will update the class attribute
# and the change will reflect in all the objects, as objects don't have their own copies
Family_Member.room_count = 5
print("after updating the class attribute via the class")
print(f"{Family_Member.room_count = }")
print(f"{swayam.room_count            = }")
print(f"{siddhu.room_count            = }")
print()

# if we update this value via any of the objects, it will create a separate copy of this for that object
# teh change will not reflect in other objects, as the original class attribute is unchanged
siddhu.room_count = 6
print("after updating the object attribute via an object (for siddhu)")
print(f"{Family_Member.room_count = }")
print(f"{swayam.room_count            = }")
print(f"{siddhu.room_count            = }")
print()

# if we now update this value via the class, it will update the class attribute
# and the change will reflect only for those objects that don't have their own copy
# and for the objects having their own copies, they will remain unchanged
Family_Member.room_count = 7
print("after updating the class attribute via the class again")
print(f"{Family_Member.room_count = }")
print(f"{swayam.room_count            = }")
print(f"{siddhu.room_count            = }")
print()
